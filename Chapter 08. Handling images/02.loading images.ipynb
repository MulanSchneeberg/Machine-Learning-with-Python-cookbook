# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread('../sim_data/images/plane.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Fundamentally, images are data and when we use imread we convert that data
# into a data type we are very familiar with—a NumPy array

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image[0:2]
# Out:
# array([[140, 136, 146, ..., 132, 139, 134],
#        [144, 136, 149, ..., 142, 124, 126]], dtype=uint8)

# %% [markdown]
# The resolution of our image was 3600 × 2270, the exact dimensions of our
# matrix:

# %%
image.shape
# Out:
# (2270, 3600)

# %%
image[0].shape
# Out:
# (3600,)

# %% [markdown]
# What does each element in the matrix actually represent? In grayscale images,
# the value of an individual element is the pixel intensity. Intensity values range
# from black (0) to white (255). For example, the intensity of the top-rightmost
# pixel in our image has a value of 140

# %%
image[0,0]
# Out:
# 140

# %% [markdown]
# In the matrix, each element contains three values corresponding to blue, green,
# red values (BGR)

# %%
# Load image in color
image_bgr = cv2.imread("../sim_data/images/plane.jpg", cv2.IMREAD_COLOR)

# %%
image_bgr.shape
# Out:
# (2270, 3600, 3)

# %%
image_bgr[0]
# Out:
# array([[195, 144, 111],
#        [191, 140, 107],
#        [201, 150, 117],
#        ...,
#        [187, 136, 103],
#        [194, 143, 110],
#        [189, 138, 105]], dtype=uint8)

# %%
image_bgr[0][0]
# Out:
# array([195, 144, 111], dtype=uint8)

# %% [markdown]
# One small caveat: by default OpenCV uses BGR, but many image applications
# —including Matplotlib—use red, green, blue (RGB), meaning the red and the
# blue values are swapped. To properly display OpenCV color images in
# Matplotlib, we need to first convert the color to RGB (apologies to hardcopy
# readers):

# %%
# Convert to RGB
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
# Show image
plt.imshow(image_rgb), plt.axis("off")
plt.show()
